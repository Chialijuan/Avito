# %%
from __future__ import unicode_literals

import multiprocessing as mp
import pandas as pd
import string
from stop_words import get_stop_words
import regex as re
from contextlib import closing

# %%
pd.options.display.max_colwidth = -1
pd.options.display.max_columns = None

# %%
filepath = '~/Documents/Avito/'
item_info = pd.read_csv(filepath+'ItemInfo_train.csv', encoding='utf-8')
# item_info.tail()

# %%
# Russian Stopwords
ru_stopwords = get_stop_words('russian')

# %%
def remove_punctuation(text):
    return re.sub(ur"\p{P}+", "", text)

# %%
def clean_text(doc):
    try:
        docs = remove_punctuation(doc)
        docs = docs.lower().split(' ')
        return [tok for tok in docs if tok not in ru_stopwords]
    except Exception as e :
        print(doc)
        print(e)
        pass

# %%
item_info['description']=item_info['description'].fillna('None')

# %%
description = item_info['description']

# %%
with closing(mp.Pool(4)) as p:
    item_info['description_clean'] = p.imap(clean_text,description)
    p.terminate()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-b4c46ed24400> in <module>()
# ----> 1 with closing(mp.Pool(4)) as p:
#       2     item_info['description_clean'] = p.imap(clean_text,description)
#       3     p.terminate()
#
# /home/juan/anaconda2/lib/python2.7/multiprocessing/__init__.pyc in Pool(processes, initializer, initargs, maxtasksperchild)
#     230     '''
#     231     from multiprocessing.pool import Pool
# --> 232     return Pool(processes, initializer, initargs, maxtasksperchild)
#     233
#     234 def RawValue(typecode_or_type, *args):
#
# /home/juan/anaconda2/lib/python2.7/multiprocessing/pool.pyc in __init__(self, processes, initializer, initargs, maxtasksperchild)
#     157         self._processes = processes
#     158         self._pool = []
# --> 159         self._repopulate_pool()
#     160
#     161         self._worker_handler = threading.Thread(
#
# /home/juan/anaconda2/lib/python2.7/multiprocessing/pool.pyc in _repopulate_pool(self)
#     221             w.name = w.name.replace('Process', 'PoolWorker')
#     222             w.daemon = True
# --> 223             w.start()
#     224             debug('added worker')
#     225
#
# /home/juan/anaconda2/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         _current_process._children.add(self)
#     132
#
# /home/juan/anaconda2/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
item_info
# Out:
#      itemID  categoryID                                             title  \
# 0    1       81          Продам Камаз 6520
# 1    3       14          Yamaha r6
# 2    4       84          iPhone 3gs 8gb
# 3    7       84          Xiaomi Mi4 3гб RAM + 16гб ROM белый
# 4    8       39          Лыжные ботинки
# 5    9       39          Сноуборд ботинки Nitro Team 10 us
# 6    12      9           LADA Priora, 2015
# 7    15      32          Телевизор
# 8    16      27          Шуба мутоновая
# 9    19      88          Массажная накидка Beurer mg
# 10   20      27          Новые. Белоснежные. Идеальное качество
# 11   21      29          2 пары обуви
# 12   22      27          Продаю вечерние туфли
# 13   26      33          Вьетнам
# 14   28      27          Полупальто
# 15   29      9           Daewoo Matiz, 2008
# 16   32      27          Пальто демисезонное
# 17   33      84          Дисплей Nokia Lumia+ тачскрин с рамкой оригинал
# 18   35      36          Uriah Heep - Very Eavy, Very Umble (Ge) Swirl
# 19   39      36          Шарф Россия трикотажный белый
# 20   40      84          iPhone 5
# 21   41      32          Музыкальный центр philips
# 22   42      28          Часы Michael Kors арт. MK-010
# 23   44      27          Летняя туника
# 24   45      90          Вислоухая красавица
# 25   50      29          Модные кеды
# 26   51      89          Щеночки звоночки
# 27   53      114         Покрытие ногтей шеллаком
# 28   55      19          Виброшлифмашина Makita BO4566
# 29   56      29          Zara
# ..   ..      ..           ...
# 470  862     20          Книжные полки
# 471  863     24          1-к квартира, 30 м², 3/5 эт.
# 472  864     99          Оригинальные картриджи для EpsonAcuLaser Cx21
# 473  865     19          Металлические гаражи л90
# 474  866     23          Комната 11 м² в 6-к, 2/4 эт.
# 475  867     30          Велосипед
# 476  869     10          Стойки 2114 15 10
# 477  875     26          Участок 10 сот. (ИЖС)
# 478  877     84          Samsung Galaxy S4 Mini
# 479  878     29          Geox Продам размер 29
# 480  880     40          Парикмахерское кресло "Таня II"
# 481  881     28          Кольцо с Бриллиантами 1.00 карат, Mодель DP 7260
# 482  883     29          Шорты Topolino 110-116
# 483  884     20          Люлька
# 484  886     32          Акустика warfadale 8.3 фронт
# 485  888     112         Разнорабочий
# 486  889     30          Roan Marita 2 в 1, голубая с черным, Польша кт
# 487  891     10          Басовик
# 488  892     29          Комбинезон демисезонный
# 489  893     112         Курьер, водитель вс, бармен и т. д
# 490  895     42          Магазин автозапчасти на авторынке фортуна, 45 м²
# 491  896     27          Мужская куртка
# 492  897     10          Стартер
# 493  901     21          Отличный холодильник Саратов
# 494  902     101         Трансформер флеш-память 16 Гигов
# 495  903     84          Чехлы Ted Baker для iPhone 6/6s
# 496  906     9           KIA cee'd, 2014
# 497  910     36          Полтинник 1925 года
# 498  914     24          1-к квартира, 36 м², 2/5 эт.
# 499  916     21          Беспроводная машинка
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          description  \
# 0    Продам Камаз 6520 20 тонн
# 1    Весь в тюнинге.
# 2    Телефон в хорошем состоянии, трещин и сколов нет, за все время менялся только аккумулятор(поэтому заряд держит хорошо), остальное все родное, в целом работает отлично! В комплекте кабель. Обмен не интересен. Лежит без дела, только продажа.
# 3    Отличный подарок на новый год от "китайской apple"\nНовый в упаковке. Коробку вместе вскроем)\nЭкран: 5 дюймов, 1080p, Sharp/JDI OGS (Возможно использование в перчатках)\nЦвет корпуса: белый\nМатериалы корпуса: пластик, металл, стекло\n\nПроцессор: Qualcomm Snapdragon 801 (8X74AC, 2.5Ггц)\nВидео: Adreno 330 (578 Мгц)\nОЗУ: 3Гб (LPDDR3 933Мгц)\nПамять: 16Гб (eMMC 5.0)\n\nКамера задняя: 13Мп (Sony IMX214, f1.8, 6 линз)\nКамера передняя: 8Мп (Sony IMX219, f1.8, 5 линз)\n\nWiFi: 802.11 a/b/g/n/ac 2.4/5Ггц\nBluetooth: 4.0\nНавигация: GPS/Glonass\nСенсоры: ИК-Порт, Датчик освещенности, Барометр, Компас, Датчик силы тяжести\n\nСимкарта: MicroSIM\n\nАккумулятор: 3080 мАч (быстрая зарядка при 9V/1.2A или 5V/2A)\n\nДополнительно: Поддержка Smart Cover Case\n\nШирина: 68,5 мм\nВысота: 139.2 мм\nТолщина: 8.9 мм\nВес: 149 г\nБез 4G
# 498  [сдается, однокомнатная, квартира, длительный, срок, , улица, филиппова, дом, 16, 20000, руб, включено]
# 499  [абсолютно, новая, машинка, стрижки, волос\nвыиграли, акции, забирать, калининском, районе]
#
# [500 rows x 12 columns]

# %%
item_info['description_clean'] = item_info['description'].apply(clean_text)

# %%
item_info.to_csv('item_info2_train.csv')

# %%
item_info.iloc[0:5]
# Out:
#    itemID  categoryID                                title  \
# 0  1       81          Продам Камаз 6520
# 1  3       14          Yamaha r6
# 2  4       84          iPhone 3gs 8gb
# 3  7       84          Xiaomi Mi4 3гб RAM + 16гб ROM белый
# 4  8       39          Лыжные ботинки
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       description  \
# 0  Продам Камаз 6520 20 тонн
# 1  Весь в тюнинге.
# 2  Телефон в хорошем состоянии, трещин и сколов нет, за все время менялся только аккумулятор(поэтому заряд держит хорошо), остальное все родное, в целом работает отлично! В комплекте кабель. Обмен не интересен. Лежит без дела, только продажа.
# 3  Отличный подарок на новый год от "китайской apple"\nНовый в упаковке. Коробку вместе вскроем)\nЭкран: 5 дюймов, 1080p, Sharp/JDI OGS (Возможно использование в перчатках)\nЦвет корпуса: белый\nМатериалы корпуса: пластик, металл, стекло\n\nПроцессор: Qualcomm Snapdragon 801 (8X74AC, 2.5Ггц)\nВидео: Adreno 330 (578 Мгц)\nОЗУ: 3Гб (LPDDR3 933Мгц)\nПамять: 16Гб (eMMC 5.0)\n\nКамера задняя: 13Мп (Sony IMX214, f1.8, 6 линз)\nКамера передняя: 8Мп (Sony IMX219, f1.8, 5 линз)\n\nWiFi: 802.11 a/b/g/n/ac 2.4/5Ггц\nBluetooth: 4.0\nНавигация: GPS/Glonass\nСенсоры: ИК-Порт, Датчик освещенности, Барометр, Компас, Датчик силы тяжести\n\nСимкарта: MicroSIM\n\nАккумулятор: 3080 мАч (быстрая зарядка при 9V/1.2A или 5V/2A)\n\nДополнительно: Поддержка Smart Cover Case\n\nШирина: 68,5 мм\nВысота: 139.2 мм\nТолщина: 8.9 мм\nВес: 149 г\nБез 4G
# 4  Лыжные ботинки в хорошем состоянии, 34 размер
#
#                                   images_array  \
# 0  1064094, 5252822, 6645873, 6960145, 9230265
# 1  11919573, 14412228, 3204180, 6646877
# 2  14384831, 6102021
# 3  NaN
# 4  13718854, 4787310
#
#                                                    attrsJSON     price  \
# 0  {"Вид техники":"Грузовики"}                                300000.0
# 1  {"Вид техники":"Мотоциклы", "Вид мотоцикла":"Спортивные"}  300000.0
# 2  {"Вид телефона":"iPhone"}                                  3500.0
# 3  {"Вид телефона":"Другие марки"}                            13500.0
# 4  {"Вид товара":"Зимние виды спорта"}                        500.0
#
#    locationID  metroID        lat        lon  \
# 0  648140     NaN       64.686946  30.815924
# 1  639040     NaN       55.678037  37.256548
# 2  640650     NaN       56.239398  43.460458
# 3  662210     NaN       55.777170  37.586194
# 4  624360     NaN       55.777170  37.586194
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       description_clean
# 0  [продам, камаз, 6520, 20, тонн]
# 1  [тюнинге]
# 2  [телефон, хорошем, состоянии, трещин, сколов, менялся, аккумуляторпоэтому, заряд, держит, остальное, родное, целом, работает, отлично, комплекте, кабель, обмен, интересен, лежит, дела, продажа]
# 3  [отличный, подарок, новый, китайской, apple\nновый, упаковке, коробку, вместе, вскроем\nэкран, 5, дюймов, 1080p, sharpjdi, ogs, возможно, использование, перчатках\nцвет, корпуса, белый\nматериалы, корпуса, пластик, металл, стекло\n\nпроцессор, qualcomm, snapdragon, 801, 8x74ac, 25ггц\nвидео, adreno, 330, 578, мгц\nозу, 3гб, lpddr3, 933мгц\nпамять, 16гб, emmc, 50\n\nкамера, задняя, 13мп, sony, imx214, f18, 6, линз\nкамера, передняя, 8мп, sony, imx219, f18, 5, линз\n\nwifi, 80211, abgnac, 245ггц\nbluetooth, 40\nнавигация, gpsglonass\nсенсоры, икпорт, датчик, освещенности, барометр, компас, датчик, силы, тяжести\n\nсимкарта, microsim\n\nаккумулятор, 3080, мач, быстрая, зарядка, 9v12a, 5v2a\n\nдополнительно, поддержка, smart, cover, case\n\nширина, 685, мм\nвысота, 1392, мм\nтолщина, 89, мм\nвес, 149, г\nбез, 4g]
# 4  [лыжные, ботинки, хорошем, состоянии, 34, размер]

# %% [markdown]
# ### Word2Vec
# - compute similarity between 2 documents (`description`)

# %%
from gensim import models, similarities
# Out:
# Using TensorFlow backend.

# %%
description = item_info['description_clean'].tolist()

# %%
model = models.word2vec.Word2Vec(description, sg=1, size=75, window =5,
                                 min_count=1, workers=3,
                                seed=1)

# %%
model.wv['телефон']
# Out:
# array([  4.56245244e-03,   1.12888229e-04,  -1.73422362e-04,
#         -1.13194459e-03,  -6.64874911e-03,   2.02879752e-03,
#         -6.50658039e-03,  -2.95225211e-04,   5.65594248e-03,
#         -3.88679182e-05,   5.33412304e-03,   3.92189948e-03,
#          2.83649471e-03,  -6.55995263e-03,   3.41940159e-03,
#         -6.05659001e-03,   5.54591324e-03,   1.74728560e-03,
#         -1.08530582e-03,   6.22847397e-03,   1.47729181e-03,
#          3.51134408e-03,  -3.35012702e-03,   4.73723689e-04,
#         -5.22524212e-03,  -1.04303763e-03,  -4.55521606e-03,
#          3.99151864e-03,  -2.51289434e-03,   1.73317327e-03,
#          1.40472222e-03,  -2.88329972e-03,  -4.33313148e-03,
#         -6.07129466e-03,  -2.71472335e-03,   2.86939042e-03,
#          5.80058899e-03,  -3.06437491e-03,   4.25369857e-04,
#          4.12389217e-03,  -4.90475493e-03,  -5.61304204e-03,
#          5.13112405e-03,   1.07095321e-03,   1.34411699e-03,
#          4.71958751e-03,  -9.08518443e-04,  -2.46188487e-03,
#          6.34095958e-03,   3.82440817e-03,  -2.83343159e-03,
#         -5.89271216e-03,   5.70709771e-03,  -6.38122321e-04,
#          9.36291879e-04,  -1.06538902e-03,   5.63497422e-03,
#         -7.29186228e-04,  -4.59039165e-03,  -1.35887938e-03,
#         -3.64457467e-03,  -4.86630807e-03,   4.99453442e-03,
#         -6.20396202e-03,  -5.71666658e-03,  -2.08825595e-03,
#         -1.83448021e-04,   3.95809347e-03,   5.46818972e-03,
#         -1.15928924e-05,  -1.17548695e-03,   1.35690649e-03,
#         -5.33510931e-04,  -5.81002701e-03,   5.87582169e-03], dtype=float32)
