# %%
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
filepath = '~/Documents/Avito/'

# %% [markdown]
# ## Initial testing on 400 rows

# %%
item_info = pd.read_csv(filepath+'ItemInfo_train.csv', nrows=400)
item_info.tail(3)
# Out:
#      itemID  categoryID                                             title  \
# 397  732     33          Греция. Родос. 2взр. Все вкл.10ноч. из Белгорода
# 398  734     10          Мотокомбинезон женский Skintan
# 399  735     112         Водитель на личном микроавтобусе
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             description  \
# 397  Греция. Родос. ALDEMAR PARADISE VILLAGE 5*\nДата вылета: 12.07.2016, 10 ночей. Стоимость тура за 2 взр.\nГород вылета: Белгород. Питание: AI - Все Включено\nТип номера: Double Room Garden View\nРазмещение: 2 взрослых\nРоскошный пятизвездочный отель на берегу моря. Великолепные виды, комфортные номера, 7 открытых бассейнов с морской и пресной водой, множество ресторанов и баров, услуги для детей (детский клуб, водная горка, анимация), детский ресторан, интернет, много спорта, анимация для взрослых, развлекательные программы и шоу. Подойдет для эксклюзивного отдыха любой категории туристов\nРасположение: \nВосточное побережье острова, р-н Каллифея, 6 км от г. Родос, 20 км от международного аэропорта Родоса.\nТерритория отеля: \n5 ресторанов (4 а’ля карт); 2 бара; 3 конференц-зала (до 300 персон); 8 бассейнов (1 крытый с подогревом в Aldemar Amilia Mare, 7 открытых с морской водой); 1 водная горка (83 м); 2 теннисных корта (с кварцевым покрытием); SPA-центр; услуги врача (по вызову, платно); прачечная (платно); лифт; обслуживание номеров; Wi-Fi в лобби (бесплатно); магазины\nВ номере: \nБалкон/терраса; Ванна/душ: ванна, банные принадлежности Aldemar; Кондиционер: (июнь-сентябрь); Мини-бар: по запросу; Спутниковое ТВ; Музыкальный канал; Телевизор; Телефон; Фен; Холодильник\nБесплатные услуги: \nтеннисный корт; теннисные мячи и ракетки; настольный теннис; дартс; баскетбол; аэробика; аквааэробика; футбольное поле; поле для мини-футбола; мини-гольф; развлекательные программы\nПлатные услуги: \nфитнес центр; сауна; джакузи; турецкая баня; массаж; уроки тенниса; бильярд; водные лыжи (с лицензией); серфинг (с лицензией); каноэ; водное поло; верховая езда (за пределами отеля); гольф (18 лунок, за пределами отеля)\nДля детей: \n1 открытый бассейн; водная горка (83 м); мини-клуб (возраст 4-12 лет); в ресторане – детское кресло; детское меню; детская площадка; развлекательные программы\nТипы номеров: \nВсего 200 номеров: Double Rooms GV/SV/PF/SP (~21 кв.м) , Family Apartments (~46 кв.м).; В номерах: кондиционер (15/06-15/09), две односпальные кровати, ванная комната (ванна), фен, банные принадлежности Aldemar, спутниковое телевидение с музыкальными каналами, прямой телефон, мини-бар (по запросу – за доплату), холодильник, сейф, меблированный балкон/веранда.; Family Apartment Двухкомнатный номер, комнаты разделены стенкой с окном и дверью, просторная ванная комната (ванна и отдельная душевая).  Возможное размещение - 2-5 человек.; По прибытии в номерах: банный набор (мыло, шампунь, гель для душа, пилочка для ногтей, шапочка для душа, ватные палочки и швейный набор).\nПляж: \nПесчано-галечный: При отеле, песчано-галечный. Душевые, кабинки для переодевания. Спасатели на пляже.; Лежаки: бесплатно; Зонтики: бесплатно; Пляжные полотенца: под залог; Кабинки
# 398  Пр-во Англия.\nКожа.\nРаздельный.\nЗащита:локти,колени,плечи,спина,бедра.\nРазмер XXS.Очень маленький размер!!!
# 399  Ищу работу на микроавтобусе. Доставка грузов. пассажира перевозки. Город, межгород, районы
#
#                                    images_array  \
# 397  13295049, 4102918, 60870, 9471054, 974432
# 398  4193194, 4444640, 5909335, 643937, 8960569
# 399  NaN
#
#                                                                                                                                                                                                                                                       attrsJSON  \
# 397  {"Вид товара":"Путешествия"}
# 398  {"Вид товара":"Экипировка"}
# 399  {"Образование":"Среднее специальное", "Пол":"Мужской", "Возраст":"33", "Переезд":"Возможен", "Готовность к командировкам":"Готов", "Опыт работы":"14", "Гражданство":"Россия", "Сфера деятельности":"Транспорт, логистика", "График работы":"Полный день"}
#
#         price  locationID  metroID        lat        lon
# 397  158889.0  623430     NaN       50.584549  36.573676
# 398  14000.0   637640      763.0    55.777170  37.586194
# 399 NaN        622170     NaN       51.516998  81.200973

# %% [markdown]
# ### Mapping for parentCategoryID, regionID

# %%
cat = pd.read_csv(filepath+'Category.csv')
location = pd.read_csv(filepath+'Location.csv')

item_pairs =pd.read_csv(filepath+'ItemPairs_train.csv', nrows=400)
item_pairs.rename(columns={'itemID_1':'itemID'}, inplace=True)

# %%
df = pd.merge(pd.merge(pd.merge(item_info,cat, on='categoryID'),
              location, on='locationID'),
              item_pairs, on='itemID')

df.tail()
# Out:
#      itemID  categoryID                                         title  \
# 395  358     20          Шкаф угловой новый
# 396  457     20          Стенка
# 397  263     98          Игровой Ноутбук Packard Bell EasyNote TV11HC
# 398  263     98          Игровой Ноутбук Packard Bell EasyNote TV11HC
# 399  437     82          Зерно ржи для проращивания 500г
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           description  \
# 395  Ширина, мм\n900\nВысота, мм\n2200\nГлубина,мм\n900\nМатериал: ЛДСП с накладками МДФ.\nДоставка 3-5 дней.\nЦвет: Орех, Бук бавария, беленый дуб, дуб беленый/венге.
# 396  Продаётся срочно! Совершенно новая, ещё с этикетками. Продаём, т.К не подошла под интерьер. Разборку и сборку и доставку оплатим сами.
# 397  ПРОДАЮ ОЧЕНЬ СРОЧНО\n###Один Косяк - не работает 4 кнопки (W,S,Q,2)###\n-состояние на 4/5\nСтоит Windows 7 Ultimate\nТанки,Dota 2, тянет на ура\n(Подробности по телефону)\n***Торг***\nПроцессор\n\nТип процессора\nCore i5\nКод процессора\n2450M\nЧастота процессора\n2.5GHz\nКоличество ядер процессора\n4\nЧипсет\nIntel HM77 \nРазмер оперативной памяти\n6 Гб\nТип памяти\nDDR3 \nКоличество слотов памяти\n2 \nЭкран\n\nРазмер экрана\n15.6 "\nРазрешение экрана\n1366x768 \nШирокоформатный экран\nесть\nСветодиодная подсветка экрана\nесть\n\nВидео\n\nВидеопроцессор\nNVIDIA GeForce GT 620M \nРазмер видеопамяти\n1024\nТип видеопамяти\nGDDR3 \nЖёсткий диск (HDD) 500Gb\nОптический привод\nWi-Fi
# 398  ПРОДАЮ ОЧЕНЬ СРОЧНО\n###Один Косяк - не работает 4 кнопки (W,S,Q,2)###\n-состояние на 4/5\nСтоит Windows 7 Ultimate\nТанки,Dota 2, тянет на ура\n(Подробности по телефону)\n***Торг***\nПроцессор\n\nТип процессора\nCore i5\nКод процессора\n2450M\nЧастота процессора\n2.5GHz\nКоличество ядер процессора\n4\nЧипсет\nIntel HM77 \nРазмер оперативной памяти\n6 Гб\nТип памяти\nDDR3 \nКоличество слотов памяти\n2 \nЭкран\n\nРазмер экрана\n15.6 "\nРазрешение экрана\n1366x768 \nШирокоформатный экран\nесть\nСветодиодная подсветка экрана\nесть\n\nВидео\n\nВидеопроцессор\nNVIDIA GeForce GT 620M \nРазмер видеопамяти\n1024\nТип видеопамяти\nGDDR3 \nЖёсткий диск (HDD) 500Gb\nОптический привод\nWi-Fi
# 399  Продукт из экопоселения\nОрехи и сухофрукты\nУрбеч, мёд, пыльца, перга\nЗамороженные полуфабрикаты натуральные\nКокосовая вода и молоко\nПродукты из экопоселения ( мука, средство для мытья волос, рожь, пшеница для проращивания) и многое другое!!!\nЕсть также доставка, подробности уточняйте по телефону.
#
#                   images_array  \
# 395  386549, 7195674, 7738049
# 396  2632217
# 397  5114133, 5446654, 8001859
# 398  5114133, 5446654, 8001859
# 399  4362029
#
#                                           attrsJSON    price  locationID  \
# 395  {"Вид товара":"Кухонные гарнитуры"}             7600.0   661100
# 396  {"Вид товара":"Предметы интерьера, искусство"}  14000.0  646520
# 397  NaN                                             14000.0  632210
# 398  NaN                                             14000.0  632210
# 399  NaN                                             75.0     637770
#
#      metroID        lat        lon  parentCategoryID  regionID  itemID_2  \
# 395 NaN       53.398579  58.988412  2                 660710    338490
# 396 NaN       55.777170  37.586194  2                 645790    2091537
# 397 NaN       56.283994  43.911043  6                 631730    4750628
# 398 NaN       56.283994  43.911043  6                 631730    1182434
# 399 NaN       55.797409  37.934462  2                 637680    5280140
#
#      isDuplicate  generationMethod
# 395  1            1
# 396  1            1
# 397  1            2
# 398  1            2
# 399  0            1

# %% [markdown]
# ###  Mapping `lat`, `lon` using MapQuest

# %%
import requests as re
from bs4 import BeautifulSoup

# %%
# Obtain api key from MapQuest

# Remove newline character when reading from file
key = open('MapQuest_Key.txt','r').read().strip()
osm = ('http://www.mapquestapi.com/geocoding/v1/reverse?key='+key+'&location=')

# %% [markdown]
# ### Feature: Street, Neighborhood, City, State, PostalCode, GeocodeQuality

# %%
def latlon(lat,lon, code):
    srch = osm + str(lat)+','+ str(lon)+'&outFormat=xml'
#     print(srch)
    r = re.get(srch)
    soup = BeautifulSoup(r.content,'lxml') 
    return get_add(soup, code)

# %%
def get_add(soup,code):
    return {'Street'+code: get_str(soup.street),
        'Neighborhood'+code: get_str(soup.find(type="Neighborhood")),
        'City'+code: get_str(soup.find(type="City")),
        'State'+code:get_str(soup.find(type="State")),
           'postalCode'+code: get_str(soup.postalcode),
           'geocodeQuality'+code: get_str(soup.geocodequality),}

# %%
def get_str(tag):
    if tag is None:
        return 'Nil'
    else:
        return tag.string

# %%
# lat lon should be in str
def df_latlon(df,lat,lon,code):
    df_ll = df.apply(lambda x: pd.Series(latlon(x[lat], x[lon], code)), axis=1)
    return pd.concat([df,df_ll],axis=1)

# %%
df1 = df_latlon(df, 'lat', 'lon', '_x')
df1.head()
# Out:
#    itemID  categoryID                 title  \
# 0  1       81          Продам Камаз 6520
# 1  193     81          MAN TGX 18.480
# 2  3       14          Yamaha r6
# 3  291     14          Продам Stels-s450
# 4  450     30          Продам мобиль-ночник
#
#                                                                                                                                       description  \
# 0  Продам Камаз 6520 20 тонн
# 1  Продаю MAN TGX 18.480 2008 года выпуска, кпп автомат. Состояние отличное, готов к работе. Рассмотрю варианты обмена. Подробности по телефону.
# 2  Весь в тюнинге.
# 3  Продам квадр 450к\nИдеальное состояние,практически не использовался..! (Сост Нового)\nТорг при осмотре!\nПричина продажи покупка недвижимости.
# 4  Состояние нового,если снять игрушки будет просто ночник с музыкой.
#
#                                      images_array  \
# 0  1064094, 5252822, 6645873, 6960145, 9230265
# 1  1029765, 11597556, 3448022, 551083, 8444145
# 2  11919573, 14412228, 3204180, 6646877
# 3  13528926, 4615652, 6856546
# 4  10533554, 11351624, 12053366, 4907365, 5647588
#
#                                                    attrsJSON      price  \
# 0  {"Вид техники":"Грузовики"}                                300000.0
# 1  {"Вид техники":"Тягачи"}                                   2400000.0
# 2  {"Вид техники":"Мотоциклы", "Вид мотоцикла":"Спортивные"}  300000.0
# 3  {"Вид техники":"Квадроциклы"}                              170000.0
# 4  {"Вид товара":"Игрушки"}                                   600.0
#
#    locationID  metroID        lat        lon  parentCategoryID  regionID  \
# 0  648140     NaN       64.686946  30.815924  1                 648070
# 1  648760     NaN       56.637263  47.886673  1                 648730
# 2  639040     NaN       55.678037  37.256548  1                 637680
# 3  638220     NaN       55.744272  38.015894  1                 637680
# 4  638220     NaN       55.744272  38.015894  5                 637680
#
#    itemID_2  isDuplicate  generationMethod       City_x Neighborhood_x  \
# 0  4112648   1            1                 None         None
# 1  3918495   1            1                 Yoshkar-Ola  None
# 2  1991275   1            1                 Odintsovo    None
# 3  562789    1            1                 Balashikha   None
# 4  5959208   1            1                 Balashikha   None
#
#                          State_x                 Street_x geocodeQuality_x  \
# 0  Northwestern Federal District  None                     STATE
# 1  Mari El                        бульвар Победы           STREET
# 2  Moscow Oblast                  Marshala Jhukova Street  STREET
# 3  Moscow Oblast                  Саввинское шоссе         STREET
# 4  Moscow Oblast                  Саввинское шоссе         STREET
#
#   postalCode_x
# 0  None
# 1  424002
# 2  143000
# 3  143986
# 4  143986

# %% [markdown]
# ### Merging ItemID_2 info with ItemID_1

# %%
cat2 = cat.rename(columns={'categoryID':'categoryID_y'})
location2 = location.rename(columns={'locationID':'locationID_y'})

# %%
item_infofull = pd.read_csv(filepath+'ItemInfo_train.csv')
item_infofull.rename(columns={'itemID':'itemID_2'}, inplace=True)

df2 = pd.merge(pd.merge(pd.merge(df1,item_infofull, on='itemID_2'),
               cat2, on='categoryID_y'),
               location2, on='locationID_y')

# %%
df2 = df2.drop(['attrsJSON_x','metroID_x','attrsJSON_y','metroID_y'],axis=1)

# %%
df3 = df_latlon(df2, 'lat_y', 'lon_y', '_y')
df3.tail()
# Out:
#      itemID  categoryID_x                                       title_x  \
# 395  182     89            Той терьер
# 396  194     89            Девочка-медвежонок
# 397  263     98            Игровой Ноутбук Packard Bell EasyNote TV11HC
# 398  103     25            Дом 170 м² на участке 10 сот.
# 399  103     25            Дом 170 м² на участке 10 сот.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         description_x  \
# 395  Маленький мальчик ждёт свои любящие заботливые ручки!!!шустрый озорной малыш будет хорошим другом вашей семьи!!!торг
# 396  Девочка рождена 30.12.2015г.Необыкновенно красивая,прикус норма,набивная шубка,игривая,от породистых родителей с родословной РКФ.Приучена к пеленке.Щенок ждет Вас в г.Алексин, доставки в другие города нет.Все вопросы по тел.
# 397  ПРОДАЮ ОЧЕНЬ СРОЧНО\n###Один Косяк - не работает 4 кнопки (W,S,Q,2)###\n-состояние на 4/5\nСтоит Windows 7 Ultimate\nТанки,Dota 2, тянет на ура\n(Подробности по телефону)\n***Торг***\nПроцессор\n\nТип процессора\nCore i5\nКод процессора\n2450M\nЧастота процессора\n2.5GHz\nКоличество ядер процессора\n4\nЧипсет\nIntel HM77 \nРазмер оперативной памяти\n6 Гб\nТип памяти\nDDR3 \nКоличество слотов памяти\n2 \nЭкран\n\nРазмер экрана\n15.6 "\nРазрешение экрана\n1366x768 \nШирокоформатный экран\nесть\nСветодиодная подсветка экрана\nесть\n\nВидео\n\nВидеопроцессор\nNVIDIA GeForce GT 620M \nРазмер видеопамяти\n1024\nТип видеопамяти\nGDDR3 \nЖёсткий диск (HDD) 500Gb\nОптический привод\nWi-Fi
# 398  Продам дом с.Троицкая ул.Тутаева новый дом рядом две школы садик фитнес клуб от центральной трассы дом расположен метров сто продаю связи долгов за 2.700 отдам
# 399  Продам дом с.Троицкая ул.Тутаева новый дом рядом две школы садик фитнес клуб от центральной трассы дом расположен метров сто продаю связи долгов за 2.700 отдам
#
#                                          images_array_x    price_x  \
# 395  10392879                                            4500.0
# 396  1576787, 6191208, 6411740                           21000.0
# 397  5114133, 5446654, 8001859                           14000.0
# 398  53314, 5725170, 6074414, 6779848, 7916713, 8090301  2800000.0
# 399  53314, 5725170, 6074414, 6779848, 7916713, 8090301  2800000.0
#
#      locationID_x      lat_x      lon_x  parentCategoryID_x  regionID_x  \
# 395  637440        55.777170  37.586194  35                  637260
# 396  658080        54.193802  37.619028  35                  657610
# 397  632210        56.283994  43.911043  6                   631730
# 398  653317        43.315854  45.067202  4                   628455
# 399  653317        43.315854  45.067202  4                   628455
#
#      itemID_2  isDuplicate  generationMethod               City_x  \
# 395  2393536   1            1                 Tverskoy District
# 396  5609286   1            1                 Tula
# 397  1182434   1            2                 Nizhny Novgorod
# 398  1043451   1            1                 Ordzhonikidzevskaya
# 399  3264384   1            1                 Ordzhonikidzevskaya
#
#     Neighborhood_x                 State_x             Street_x  \
# 395  None           Moscow                  3 Лесная улица
# 396  None           Tula Oblast             Менделеевская улица
# 397  None           Nizhny Novgorod Oblast  45 Кировская улица
# 398  None           Ingushetia              Зелёная улица
# 399  None           Ingushetia              Зелёная улица
#
#     geocodeQuality_x postalCode_x  categoryID_y  \
# 395  POINT            125047       89
# 396  STREET           300041       89
# 397  POINT            603135       98
# 398  STREET           None         25
# 399  STREET           None         25
#
#                                           title_y  \
# 395  Той терьер
# 396  Шпиц-медвежонок
# 397  Игровой Ноутбук Packard Bell EasyNote TV11HC
# 398  Дом 160 м² на участке 10 сот.
# 399  Дом 1317 м² на участке 10 сот.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              description_y  \
# 395  Маленький озорной мальчик ищет добрые заботливые ручки.торг
# 396  Девочка рождена 30.12.2015 года. Короткая мордашка, набивная шубка, ножнецеобразный прикус,без недостатков.Мама и папа с родословной РКФ. Будет рада обрести любящего хозяина.Доставки в другие города нет. Все вопросы по тел.
# 397  ПРОДАЮ ОЧЕНЬ СРОЧНО\nПричина:срочно нужны деньги\nза такую цену такой ноутбук не найдете\n###Один Косяк - не работает 4 кнопки (W,S,Q,2)###\n-состояние на 4/5\nСтоит Windows 7 Ultimate\nТанки,Dota 2, тянет на ура\n(Подробности по телефону)\n***Торг***\nПроцессор\n\nТип процессора\nCore i5\nКод процессора\n2450M\nЧастота процессора\n2.5GHz\nКоличество ядер процессора\n4\nЧипсет\nIntel HM77 \nРазмер оперативной памяти\n6 Гб\nТип памяти\nDDR3 \nКоличество слотов памяти\n2 \nЭкран\n\nРазмер экрана\n15.6 "\nРазрешение экрана\n1366x768 \nШирокоформатный экран\nесть\nСветодиодная подсветка экрана\nесть\n\nВидео\n\nВидеопроцессор\nNVIDIA GeForce GT 620M \nРазмер видеопамяти\n1024\nТип видеопамяти\nGDDR3 \nЖёсткий диск (HDD) 500Gb\nОптический привод\nWi-Fi
# 398  Продам дом с.Троицкая ул.Тутаева новый дом рядом все школа дет сад магазины все что нужно человеку можно бартер предлагайте торг имеется
# 399  Продам дом с.Троицкая ул.Тутаева новый дом рядом две школы садик фитнес клуб от центральной трассы дом расположен метров сто продаю связи долгов срочно
#
#                                               images_array_y    price_y  \
# 395  3992827                                                  5500.0
# 396  4085846, 6919845, 7540617                                21000.0
# 397  128368, 4673223, 5070122                                 13500.0
# 398  10470414, 12329644, 13747437, 14370763, 2019369, 944781  2800000.0
# 399  11554137, 12503233, 234340, 4541596, 4699664, 7455505    2700000.0
#
#      locationID_y      lat_y      lon_y  parentCategoryID_y  regionID_y  \
# 395  637440        52.603587  39.597603  35                  637260
# 396  657630        54.511823  37.051400  35                  657610
# 397  632210        55.777170  37.586194  6                   631730
# 398  653317        43.315854  45.067202  4                   628455
# 399  653317        43.315854  45.067202  4                   628455
#
#                   City_y Neighborhood_y         State_y            Street_y  \
# 395  Lipetsk              None           Lipetsk Oblast  Первомайская улица
# 396  Aleksin              None           Tula Oblast     улица Некрасова
# 397  Tverskoy District    None           Moscow          3 Лесная улица
# 398  Ordzhonikidzevskaya  None           Ingushetia      Зелёная улица
# 399  Ordzhonikidzevskaya  None           Ingushetia      Зелёная улица
#
#     geocodeQuality_y postalCode_y
# 395  STREET           398000
# 396  STREET           301360
# 397  POINT            125047
# 398  STREET           None
# 399  STREET           None

# %%
# pd.options.display.max_colwidth = -1
pd.options.display.max_columns = None
df3.iloc[15:20]
# Out:
#     itemID  categoryID_x                                             title_x  \
# 15  64      29            Платье со шлейфом
# 16  210     29            Новые Лето р 35
# 17  210     29            Новые Лето р 35
# 18  176     36            Фарфоровая статуэтка Германия
# 19  334     36            Вин из коллекц/beatles, steve winwood/продаю обмен
#
#                                                                                                             description_x  \
# 15  Продам шикарное платье+ободок в комплекте!размер 4 (104-110)\nДорогое кружево,шлей,ободок!)платье не требует рекламы.
# 16  Новые\nЭко б/у в отл,сост р 36 р ( 22.7)
# 17  Новые\nЭко б/у в отл,сост р 36 р ( 22.7)
# 18  фарфоровая статуэтка
# 19  ответ только по телефону
#
#                                     images_array_x  price_x  locationID_x  \
# 15  1375834                                         3800.0   637640
# 16  10478227, 11699953, 12061106, 3262571, 8656633  1000.0   637640
# 17  10478227, 11699953, 12061106, 3262571, 8656633  1000.0   637640
# 18  7852960                                         2500.0   637640
# 19  3538679, 9384943                               NaN       637640
#
#         lat_x      lon_x  parentCategoryID_x  regionID_x  itemID_2  \
# 15  55.788424  37.749265  5                   637640      4419878
# 16  55.753653  37.619800  5                   637640      4323869
# 17  55.753653  37.619800  5                   637640      3856243
# 18  55.622436  37.609047  7                   637640      2653321
# 19  55.620982  37.669612  7                   637640      3205438
#
#     isDuplicate  generationMethod                                City_x  \
# 15  1            1                 Sokolinaya Gora District
# 16  1            1                 Tverskoy District
# 17  1            1                 Tverskoy District
# 18  0            1                 Chertanovo Severnoye District
# 19  0            1                 Orekhovo-Borisovo Severnoye District
#
#    Neighborhood_x State_x                         Street_x geocodeQuality_x  \
# 15  None           Moscow  Арбатско-Покровская линия        POINT
# 16  None           Moscow  Lenin's Mausoleum                POINT
# 17  None           Moscow  Lenin's Mausoleum                POINT
# 18  None           Moscow  Серпуховско-Тимирязевская линия  POINT
# 19  None           Moscow  Замоскворецкая линия             POINT
#
#    postalCode_x  categoryID_y  \
# 15  105318       29
# 16  127238       29
# 17  127238       29
# 18  117587       36
# 19  115569       36
#
#                                                title_y  \
# 15  Шикарное платье
# 16  Новые полузакрытые сандали р 35
# 17  Новые закрытые сандали р 35 (22)
# 18  Фарфоровая статуэтка Германия
# 19  Из коллекц/ beatles, freddie hubbard /продаю обмен
#
#                                                                                                                        description_y  \
# 15  Шикарное платье в комплекте ободок.дорогое кружево,шлейф,платье не требует рекламы.размер 4 (104-110)\nЦена 3600.фото по запросу
# 16  Новые кожа+ ткань  р35(22)
# 17  Новые кожа
# 18  Фарфоровая статуэтка в идеальном состоянии
# 19  Ответ только по телефону
#
#                                    images_array_y  price_y  locationID_y  \
# 15  13770212                                       3600.0   637640
# 16  10722506, 12889778, 13551619, 5497717, 607651  999.0    637640
# 17  12225993, 12547628, 1527624, 6854254, 8302900  1000.0   637640
# 18  10419329                                       2500.0   637640
# 19  12569178, 4350671                             NaN       637640
#
#         lat_y      lon_y  parentCategoryID_y  regionID_y  \
# 15  55.788424  37.749265  5                   637640
# 16  55.676265  37.762003  5                   637640
# 17  55.676265  37.762003  5                   637640
# 18  55.622436  37.609047  7                   637640
# 19  55.620982  37.669612  7                   637640
#
#                                   City_y Neighborhood_y State_y  \
# 15  Sokolinaya Gora District              None           Moscow
# 16  Maryino District                      None           Moscow
# 17  Maryino District                      None           Moscow
# 18  Chertanovo Severnoye District         None           Moscow
# 19  Orekhovo-Borisovo Severnoye District  None           Moscow
#
#                            Street_y geocodeQuality_y postalCode_y
# 15  Арбатско-Покровская линия        POINT            105318
# 16  Люблинско-Дмитровская линия      POINT            109451
# 17  Люблинско-Дмитровская линия      POINT            109451
# 18  Серпуховско-Тимирязевская линия  POINT            117587
# 19  Замоскворецкая линия             POINT            115569

# %%
df3.isDuplicate.sum()
# Out:
# 209L

# %% [markdown]
# ### Feature: Number of images identifiers that overlaps

# %%
def n_similar_images(df):
    try:
        arr1 = df.images_array_x.split(',')
        try:
            arr2 = df.images_array_y.split(',')
            return sum(a in b for a, b in zip(arr1,arr2))
        except: pass
    except: pass

# %%
num_similarimages = df3[['images_array_x','images_array_y']].apply(n_similar_images, axis=1)

# %%
num_similarimages.sum()
# Out:
# 0.0

# %% [markdown]
# ### Feature: Difference in length of image array

# %%
def diff_len_image_array(df2):
    try:
        arr1 = df2.images_array_x.split(',')
        try:
            arr2 = df2.images_array_y.split(',')
            return abs(len(arr1)-len(arr2))
        except: pass
    except: pass

# %%
df3['lendiff_imagearray'] = df3[['images_array_x','images_array_y']].apply(diff_len_image_array, axis=1)

# %% [markdown]
# ### Feature: sameCat

# %%
df3['sameCat'] = df3.apply(
    lambda x: 1 if x.categoryID_x == x.categoryID_y else 0, axis=1)

# %%
df3['sameCat'].sum()
# Out:
# 400L

# %% [markdown]
# ### Feature: sameParentCat

# %%
df3['sameParentCat'] = df3.apply(
    lambda x: 1 if x.parentCategoryID_x == x.parentCategoryID_y else 0 , axis=1)

# %%
df3['sameParentCat'].sum()
# Out:
# 400L

# %% [markdown]
# - Feature engineering done on the categories showed that `categoryID` and `parentCategoryID` is not very useful in predicting if an ad is a duplicate of the other.

# %% [markdown]
# ### Feature: priceDifference

# %%
df3['priceDifference'] = df3.apply(
    lambda x: abs(x.price_x - x.price_y), axis=1)

# %% [markdown]
# ### Feature: samelatlon
# - Checks if item pairs have the same lat and lon values

# %%
df3.apply(
    lambda x: 1 if x.lon_x == x.lon_y else 0, axis=1).sum()
# Out:
# 337L

# %% [markdown]
# ### Feature: latlonDifference
# - Compute the differences between the lat and lon values for item pairs
# using **Haversine** distance

# %%
import math

# %%
def haversine(lat1, lon1, lat2, lon2):
    r = 6371
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])
    
    dlon = (lon2-lon1)/2
    dlat = (lat2-lat1)/2
    ax = math.sin(dlat)**2 + math.cos(lat1) *math.cos(lat2) * math.sin(dlon)**2
    d = 2 * r * math.asin(math.sqrt(ax))
    return d

# %%
df3['latlonDifference'] = df3.apply(
    lambda x: haversine(x['lat_x'], x['lon_x'], x['lat_y'], x['lon_y'])
    ,axis=1)

# %%
df3[df3.latlonDifference == 0.0000].latlonDifference.count()
# Out:
# 337

# %%
df3.head()
# Out:
#    itemID  categoryID_x               title_x  \
# 0  1       81            Продам Камаз 6520
# 1  193     81            MAN TGX 18.480
# 2  3       14            Yamaha r6
# 3  291     14            Продам Stels-s450
# 4  450     30            Продам мобиль-ночник
#
#                                                                                                                                     description_x  \
# 0  Продам Камаз 6520 20 тонн
# 1  Продаю MAN TGX 18.480 2008 года выпуска, кпп автомат. Состояние отличное, готов к работе. Рассмотрю варианты обмена. Подробности по телефону.
# 2  Весь в тюнинге.
# 3  Продам квадр 450к\nИдеальное состояние,практически не использовался..! (Сост Нового)\nТорг при осмотре!\nПричина продажи покупка недвижимости.
# 4  Состояние нового,если снять игрушки будет просто ночник с музыкой.
#
#                                    images_array_x    price_x  locationID_x  \
# 0  1064094, 5252822, 6645873, 6960145, 9230265     300000.0   648140
# 1  1029765, 11597556, 3448022, 551083, 8444145     2400000.0  648760
# 2  11919573, 14412228, 3204180, 6646877            300000.0   639040
# 3  13528926, 4615652, 6856546                      170000.0   638220
# 4  10533554, 11351624, 12053366, 4907365, 5647588  600.0      638220
#
#        lat_x      lon_x  parentCategoryID_x  regionID_x  itemID_2  \
# 0  64.686946  30.815924  1                   648070      4112648
# 1  56.637263  47.886673  1                   648730      3918495
# 2  55.678037  37.256548  1                   637680      1991275
# 3  55.744272  38.015894  1                   637680      562789
# 4  55.744272  38.015894  5                   637680      5959208
#
#    isDuplicate  generationMethod       City_x Neighborhood_x  \
# 0  1            1                 None         None
# 1  1            1                 Yoshkar-Ola  None
# 2  1            1                 Odintsovo    None
# 3  1            1                 Balashikha   None
# 4  1            1                 Balashikha   None
#
#                          State_x                 Street_x geocodeQuality_x  \
# 0  Northwestern Federal District  None                     STATE
# 1  Mari El                        бульвар Победы           STREET
# 2  Moscow Oblast                  Marshala Jhukova Street  STREET
# 3  Moscow Oblast                  Саввинское шоссе         STREET
# 4  Moscow Oblast                  Саввинское шоссе         STREET
#
#   postalCode_x  categoryID_y               title_y  \
# 0  None         81            Продам Камаз 6520
# 1  424002       81            Man TGX 18.480
# 2  143000       14            Yamaha R6
# 3  143986       14            Продам stels 450H
# 4  143986       30            Продам мобиль-ночник
#
#                                                                                                                                                                                                                                                                          description_y  \
# 0  Продам Камаз 6520 20 тонн
# 1  Продаю маn TGX 18.480 2008 года выпуска, кпп автомат. Состояние отличное, готов к работе. Обмен. Подробности по телефону.
# 2  Весь в тюнинге. Возможен торг
# 3  Продаю квадроцикл,состояние нового!\nИзредка использовал для прогулок по лесу,грязи не видел!\nПокупал сам в магазине,никаких вложений не требует.\nДокументы на руках..\nПродаю по причине,беру ипотеки и покупаю недвижимость.\nЕсли без торга,то кофр отдам его стоимость 12000.
# 4  Пользовались 1 месяц,подсветка 3 режима,музыка,вибрация.крутиться вертится.
#
#                                    images_array_y    price_y  locationID_y  \
# 0  1227519, 1374615, 7072137, 8671835              300000.0   648140
# 1  10043643, 1448346, 1890733, 3048514, 3836550    2400000.0  648760
# 2  11068709, 13325040, 13783238, 206652, 9458537   330000.0   639040
# 3  11150303, 11189165, 13671950, 1990395, 8559868  168000.0   638220
# 4  14041801, 1643200                               600.0      637770
#
#        lat_y      lon_y  parentCategoryID_y  regionID_y       City_y  \
# 0  64.686946  30.815924  1                   648070      None
# 1  56.637263  47.886673  1                   648730      Yoshkar-Ola
# 2  55.678037  37.256548  1                   637680      Odintsovo
# 3  55.744272  38.015894  1                   637680      Balashikha
# 4  55.797409  37.934462  5                   637680      Balashikha
#
#   Neighborhood_y                        State_y                 Street_y  \
# 0  None           Northwestern Federal District  None
# 1  None           Mari El                        бульвар Победы
# 2  None           Moscow Oblast                  Marshala Jhukova Street
# 3  None           Moscow Oblast                  Саввинское шоссе
# 4  None           Moscow Oblast                  Советская улица
#
#   geocodeQuality_y postalCode_y  lendiff_imagearray  sameCat  sameParentCat  \
# 0  STATE            None         1.0                 1        1
# 1  STREET           424002       0.0                 1        1
# 2  STREET           143000       1.0                 1        1
# 3  STREET           143986       2.0                 1        1
# 4  STREET           141250       3.0                 1        1
#
#    priceDifference  latlonDifference
# 0  0.0              0.000000
# 1  0.0              0.000000
# 2  30000.0          0.000000
# 3  2000.0           0.000000
# 4  0.0              7.800873
